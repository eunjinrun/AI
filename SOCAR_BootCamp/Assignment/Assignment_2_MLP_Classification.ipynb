# %% [markdown]
# # Assignment 2. MLP MNIST classification - Finetuning
#
# 이번 과제는 4주차와 5주차에 배운 내용을 이용해 MLP를 구성하고 학습을 진행해 봅니다.
#
# 2가지 종류의 MNIST 데이터에 대해 다양한 모델 구조를 적용해 학습을 진행해 보고 여러 기법들에 따라 어떻게 학습 양상이 달라지는 지 분석해 봅니다.
#
# 여러 모델 구조와 기법들 중에서 최적의 조건을 찾아 성능을 향상 시키는 것이 과제의 목표입니다.
#
# AI 엔지니어로서 여러분은 데이터의 특징을 분석해서 적절한 모델 구조와 다양한 hyper parameter를 결정해야 합니다. 그렇지만 아무리 insight가 좋은 엔지니어라도 데이터만 봐서는 최적의 모델 세팅을 알아낼 수는 없을 겁니다. 다양한 모델을 구성하고 직접 학습을 진행해 봐야 하고 새로운 아이디어도 적용해 볼 수 있어야 합니다.
#
# 5주차 실습에서 사용한 trainer class를 여러분의 입맛에 맞게 변형하여 각자 적용해보고 싶은 기능들의 성능을 확인해 봅시다.
#
# ### 1. Data
#
# 이번 과제는 MNIST와 FMNIST 데이터를 사용합니다.
#
# 그렇지만 다양한 종류의 데이터에 적용할 수 있는 범용적인 코드를 작성하여, 2개의 데이터 셋에 대해 코드의 큰 변형 없이 적용하는 것을 목표로 하겠습니다.
#
# 각 데이터 셋에 대해 다르게 나타날 최적의 hyperparameter setting을 찾아보도록 하겠습니다.
#
# ### 2. Model structure
#
# 기본적인 MLP 구조에서 여러분은 hidden layer를 몇 층 쌓을지, 각 layer의 width, activation function과 dropout, batch normalization의 적용 여부를 결정하셔야 합니다.
#
# 주어진 데이터에 대해 최대의 성능을 내는 어떤 설정이 존재하기는 하겠지만, 이걸 한 번에 찾는 건 어렵겠죠? 심지어 모델 초기화 등에 randomness가 존재하기 때문에 매번 미세하게 달라질 겁니다.
#
# 이러한 randomness까지는 고려하지 않더라도 모델 구조와 다른 세팅을 바꿔가며 각 데이터셋에 대해 학습을 진행하여 test dataset에 대한 성능을 확인해 보도록 하겠습니다.
#
# ### 3. Optimization procedure
#
# 이미 실습에서 확인하셨겠지만 모델 구조 외에도 어떠한 optimizer와 learning rate을 사용하느냐도 성능에 굉장히 큰 영향을 줍니다.
#
# 많이 사용되는 SGD와 Adam optimizer 외에도 다른 알고리즘들을 적용해 보겠습니다.
#
# optimizer의 종류 외에도 각 optimizer의 hyperparameter도 있지만, 이것까지는 tuning을 하지 않아도 될 것 같습니다. 이러한 hyperparameter들은 일반적으로 고정 시켜서 사용하는 추세입니다!
#
# ### 4. 평가
#
# 지금까지 언급한 경우만 고려하더라도 데이터 종류, 모델 종류, optimizer 종류, lr 까지 하여 tuning할 요소가 4가지나 됩니다.
#
# 4종류의 모델, 3종류의 optimizer와 lr을 3가지 확인한다고 하면 이미 72번의 실험을 진행해야겠네요.
#
# 때문에 이렇게 많은 실험들을 효율적으로 정리하고 실행하는 것도 굉장히 중요하답니다.
#
# 이번 과제에서는 for 문을 이용해 여러 번의 실험을 진행한 후 최적의 세팅을 찾아 학습을 한 번 더 진행하는 것으로 하겠습니다.
#
# 실제로는 다양한 hyperparameter에 대한 search를 자동으로 해주는 tool들이 개발되어 있으니 관심 있으신 분들은 찾아보셔도 좋을 것 같습니다. 이번 과제에서는 필요하지 않습니다!

# %% [markdown]
# ### Mount Drive and Import Pacakges

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

from torchvision import datasets, transforms

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Data

# %% [markdown]
# ### Load and prepare data

# %%
root = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks", "data")
root
# Out:
# '/content/drive/MyDrive/Colab Notebooks/data'

# %%
def get_data(data, root, download=True, transform=transforms.ToTensor()):
  if data.lower() == "mnist":
    train = datasets.MNIST(root=root, train=True, download=download, transform=transform)
    test = datasets.MNIST(root=root, train=False, download=download, transform=transform)
  elif data.lower() == "fmnist":
    train = datasets.FashionMNIST(root=root, train=True, download=download, transform=transform)
    test = datasets.FashionMNIST(root=root, train=False, download=download, transform=transform)
  else:
    raise ValueError(f"data name {data} is not supported.")

  return train, test

# %%
mnist_tr, mnist_test = get_data(data="MNIST", root=root)
fmnist_tr, fmnist_test = get_data(data="FMNIST", root=root)

# %% [markdown]
# ### Check datasets

# %%
def plot_mnist(data, figsize=(20, 10)):
  fig = plt.figure(figsize=figsize)
  for i in range(18):
    img = data[i][0]
    ax = fig.add_subplot(3, 6, i+1)
    ax.imshow(img.reshape(28, 28), cmap="gray")
    ax.set_title(f"Label: {data[i][1]}")
  fig.show()
  pass

# %%
plot_mnist(data=mnist_tr)

# %%
plot_mnist(data=fmnist_tr)

# %% [markdown]
# ### Split train dataset into train and valid

# %%
class mnist_dataset(Dataset):
  def __init__(self, data, targets, transform=None, target_transform=None):
    super().__init__()

    self.data = data
    self.targets = targets
    self.transform = transform
    self.target_transform = target_transform
    pass

  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    x, y = self.data[idx], self.targets[idx]

    if self.transform:
      x = self.transform(x)
    if self.target_transform:
      y = self.target_transform(y)

    return x, y

# %%
def split_train_valid(dataset, valid_ratio=0.1):
  # 이 부분을 채워 보겠습니다.
  # 실습 때 사용한 부분을 그대로 적용하셔도 되지만, 가능하다면 학습 데이터를 random하게 섞은 후에 split을 시도해보겠습니다.
  # 기존의 실습 코드는 데이터의 앞 부분을 train, 뒷 부분을 valid로 사용합니다.
  # 주의하세요, dataset의 data와 targets을 똑같이 shuffle 하셔야 원하는 label을 제대로 지정해 줄 수 있습니다!
  # 시도해 보시고 shuffle이 제대로 안 되는 것 같으면 5주차 실습에 있는 코드를 사용해 주세요.

  #n_valid = int(len(dataset) * valid_ratio)
  
  #train_data = dataset.data[:-n_valid].numpy()
  #valid_data = dataset.data[-n_valid:].numpy()
  #train_targets = dataset.targets[:-n_valid]
  #valid_targets = dataset.targets[-n_valid:]
  
  from sklearn.model_selection import train_test_split
  train_data, valid_data, train_targets, valid_targets = train_test_split(dataset.data,dataset.targets,test_size=0.9,shuffle=True,random_state=42)

  train_data = train_data.numpy()
  valid_data = valid_data.numpy()

  train = mnist_dataset(data=train_data, targets=train_targets, transform=dataset.transform, target_transform=dataset.target_transform)
  valid = mnist_dataset(data=valid_data, targets=valid_targets, transform=dataset.transform, target_transform=dataset.target_transform)

  return train, valid

# %%
mnist_train, mnist_valid = split_train_valid(dataset=mnist_tr)
fmnist_train, fmnist_valid = split_train_valid(dataset=fmnist_tr)

# %% [markdown]
# ### Check shuffling result

# %%
# 위에서 출력한 결과와 label이 그대로인지 확인해 보세요!
# Shuffle에 성공하셨다면 위와는 다른 그림들이 출력됩니다.
# 각 그림에 해당하는 label은 정확히 적용이 되는지 확인해보세요!
plot_mnist(data=mnist_train)

# %%
plot_mnist(data=fmnist_train)

# %% [markdown]
# ### Get loaders

# %%
# 필요하다면, 후에 이 부분도 수정해 보세요!
# batch size를 바꾸시면 data loader를 다시 만들어야 합니다!
# MNIST는 거의 차이가 없을 것 같은데, FMNIST는 영향을 받을 수도 있습니다!
b_size = 256

# %%
mnist = [DataLoader(dataset=d, batch_size=b_size, shuffle=True, drop_last=True) for d in [mnist_train, mnist_valid, mnist_test]]
fmnist = [DataLoader(dataset=d, batch_size=b_size, shuffle=True, drop_last=True) for d in [fmnist_train, fmnist_valid, fmnist_test]]
datas = {"mnist": mnist, "fmnist": fmnist}

# %% [markdown]
# ## 2. Model

# %% [markdown]
# ### Base model

# %%
class BaseClassifier(nn.Module):
  def __init__(self, n_class=10):
    super().__init__()

    self.name = "base"
    self.model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(28 * 28, 64),
        nn.ReLU(),
        nn.Linear(64, 64),
        nn.ReLU(),
        nn.Linear(64, n_class),
    )

  def forward(self, x):
    return self.model(x)

# %% [markdown]
# ### Customized models

# %%
class FirstClassifier(nn.Module):
  def __init__(self, n_class=10):
    super().__init__()

    self.name = "first"
    # Model을 만들어 봅시다.
    # 구조와 activation function, 그 외에 다른 기법들의 사용 유무와 사용 위치를 정할 수 있습니다.
    self.model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(28 * 28, 256),
        nn.Dropout(p=0.5),
        nn.ReLU(),
        nn.Linear(256, 128),
        nn.Dropout(p=0.5),
        nn.ReLU(),
        nn.Linear(128, n_class),
    )

  def forward(self, x):
    return self.model(x)

# FirstClassifier 말고도 다양한 모델을 만들어서 학습을 시켜보고 성능을 비교해 볼 수 있습니다.

# %%
class SecondClassifier(nn.Module):
  def __init__(self, n_class=10):
    super().__init__()

    self.name = "second"
    # Model을 만들어 봅시다.
    # 구조와 activation function, 그 외에 다른 기법들의 사용 유무와 사용 위치를 정할 수 있습니다.
    self.model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(28 * 28, 256),
        nn.BatchNorm1d(256),
        nn.ReLU(),
        nn.Linear(256, 128),
        nn.BatchNorm1d(128),
        nn.ReLU(),
        nn.Linear(128, n_class),
    )

  def forward(self, x):
    return self.model(x)

# %%
class ThirdClassifier(nn.Module):
  def __init__(self, n_class=10):
    super().__init__()

    self.name = "third"
    # Model을 만들어 봅시다.
    # 구조와 activation function, 그 외에 다른 기법들의 사용 유무와 사용 위치를 정할 수 있습니다.
    self.model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(28 * 28, 256),
        nn.BatchNorm1d(256),
        nn.Dropout(p=0.5),
        nn.ReLU(),
        nn.Linear(256, 128),
        nn.BatchNorm1d(128),
        nn.Dropout(p=0.5),
        nn.ReLU(),
        nn.Linear(128, n_class),
    )

  def forward(self, x):
    return self.model(x)

# %% [markdown]
# ### Using get_model function

# %%
def get_model(model_name):
  if model_name.lower() == "base":
    return BaseClassifier()
  elif model_name.lower() == "first":
    return FirstClassifier()
  elif model_name.lower() == "second":
    return SecondClassifier()
  elif model_name.lower() == "third":
    return ThirdClassifier()
  else:
    raise ValueError(f"model name {model_name} is not supported")

# get_model 함수가 activation function을 받고, 각 classifier를 정의할 때 activation function을 함께 넘겨주도록 만들 수도 있습니다!
# 그렇게 하면 훨씬 적은 수의 model class로 더 다양한 경우를 사용할 수 있을 것 같네요.
# 여러분이 원하는 기능을 가지도록 다양한 model class와 get_model 함수들을 코딩해 보세요!

# %% [markdown]
# ## 3. Trainer

# %% [markdown]
# ### Make trainer

# %%
class Trainer(nn.Module):
  def __init__(self, model, opt="sgd", lr=0.001, has_scheduler=False, device="cpu"):
    super().__init__()
    self.path = f"_model_{model.name}_opt_{opt}_lr_{lr}"

    self.model = model
    self.loss = nn.CrossEntropyLoss()
    self._get_optimizer(opt=opt.lower(), lr=lr)
    self.has_scheduler = has_scheduler
    if self.has_scheduler:
      self._get_scheduler()

    self.device = device
    pass

  def _get_optimizer(self, opt, lr=0.001):
    # 몇 가지 optimizer를 더 찾아서 적용해 볼까요?
    if opt == "sgd":
      self.optimizer = torch.optim.SGD(params=self.model.parameters(), lr=lr)
    elif opt == "adam":
      self.optimizer = torch.optim.Adam(params=self.model.parameters(), lr=lr)
    elif opt == "rmsprop":
      self.optimizer = torch.optim.RMSprop(params=self.model.parameters(), lr=lr)
    else:
      raise ValueError(f"optimizer {opt} is not supproted")

  def _get_scheduler(self):
    self.scheduler = torch.optim.lr_scheduler.StepLR(optimizer=self.optimizer, step_size=5, gamma=0.5, verbose=True)

  def train(self, data_name, train_loader, valid_loader, max_epochs=10):
    print("===== Train Start =====")
    history = {"train_loss": [], "train_acc": [], "valid_loss": [], "valid_acc": []}
    for e in range(max_epochs):
      train_loss, train_acc = self._train_epoch(train_loader)
      valid_loss, valid_acc = self._valid_epoch(valid_loader)

      history["train_loss"].append(train_loss)
      history["train_acc"].append(train_acc)
      history["valid_loss"].append(valid_loss)
      history["valid_acc"].append(valid_acc)

      if self.has_scheduler:
        self.scheduler.step()

      if e % 10 == 0:
        print(f"Epoch: {e}, train loss: {train_loss:>6f}, train acc: {train_acc:>3f}, valid loss: {valid_loss:>6f}, valid acc: {valid_acc:>3f}")

    self.plot_history(history, data_name, max_epochs)

  def _train_epoch(self, train_loader):
    epoch_loss, epoch_acc = 0, 0
    self.model.train()
    for (x, y) in train_loader:
      x = x.to(self.device)
      y = y.to(self.device)

      y_hat = self.model(x)
      loss = self.loss(y_hat, y)

      self.optimizer.zero_grad()
      loss.backward()
      self.optimizer.step()

      epoch_loss += loss.to("cpu").item()
      epoch_acc += (y_hat.argmax(1) == y).type(torch.float).to("cpu").mean().item()

    return epoch_loss / len(train_loader), epoch_acc / len(train_loader)
  
  def _valid_epoch(self, valid_loader):
    epoch_loss, epoch_acc = 0, 0
    self.model.eval()
    with torch.no_grad():
      for (x, y) in valid_loader:
        x = x.to(self.device)
        y = y.to(self.device)

        y_hat = self.model(x)
        loss = self.loss(y_hat, y)

        epoch_loss += loss.to("cpu").item()
        epoch_acc += (y_hat.argmax(1) == y).type(torch.float).to("cpu").mean().item()

    return epoch_loss / len(valid_loader), epoch_acc / len(valid_loader)

  def plot_history(self, history, data_name, max_epochs):
    fig = plt.figure(figsize=(10, 5))

    ax = fig.add_subplot(1, 2, 1)
    ax.plot(history["train_loss"], color="red", label="train loss")
    ax.plot(history["valid_loss"], color="blue", label="valid loss")
    ax.set_title("Loss")
    ax.legend()

    ax = fig.add_subplot(1, 2, 2)
    ax.plot(history["train_acc"], color="red", label="train acc")
    ax.plot(history["valid_acc"], color="blue", label="valid acc")
    ax.set_title("Acc")
    ax.legend()

    path = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks", "plots", f"data_{data_name}" + self.path + f"_max_epochs_{max_epochs}.png")
    plt.savefig(path, bbox_inches="tight")
    pass

  def test(self, test_loader):
    print("===== Test Start =====")
    epoch_loss, epoch_acc = 0, 0
    self.model.eval()
    with torch.no_grad():
      for (x, y) in test_loader:
        x = x.to(self.device)
        y = y.to(self.device)

        y_hat = self.model(x)
        loss = self.loss(y_hat, y)

        epoch_loss += loss.to("cpu").item()
        epoch_acc += (y_hat.argmax(1) == y).type(torch.float).to("cpu").mean().item()

    epoch_loss /= len(test_loader)
    epoch_acc /= len(test_loader)

    print(f"Test loss: {epoch_loss:>6f}, Test acc: {epoch_acc:>3f}")

# %% [markdown]
# ### Train and test

# %%
# 해당 코드는 1번만 실행해 주시면 됩니다.
p = os.path.join(os.getcwd(), "drive", "MyDrive", "Colab Notebooks", "plots")
if not os.path.isdir(p):
  os.mkdir(p)

# %%
ds = ["mnist", "fmnist"]
models = ["base","first","second","third"]
opts = ["sgd","adam","rmsprop"]
lrs = [0.001,1e-6,5e-6]
max_epochs = 30

# %%
for d in ds:
  for m in models:
    for opt in opts:
      for lr in lrs:
        model = get_model(model_name = m)
        trainer = Trainer(model=model, opt=opt, lr=lr, has_scheduler=True)
        print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
        trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
        trainer.test(test_loader=datas[d][2])
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: base, Optimizer: sgd, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 2.304239, train acc: 0.126019, valid loss: 2.303415, valid acc: 0.126376
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 2.299648, train acc: 0.147928, valid loss: 2.299189, valid acc: 0.148400
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 2.298532, train acc: 0.156590, valid loss: 2.298126, valid acc: 0.154762
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 2.296287, Test acc: 0.165565
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: mnist, Model: base, Optimizer: sgd, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.303494, train acc: 0.094260, valid loss: 2.301605, valid acc: 0.094792
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.303131, train acc: 0.094429, valid loss: 2.301630, valid acc: 0.094829
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.303074, train acc: 0.094939, valid loss: 2.301624, valid acc: 0.094792
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.300922, Test acc: 0.097556
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: mnist, Model: base, Optimizer: sgd, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.304154, train acc: 0.081352, valid loss: 2.304310, valid acc: 0.079836
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.304148, train acc: 0.080163, valid loss: 2.304294, valid acc: 0.079967
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.304043, train acc: 0.081522, valid loss: 2.304299, valid acc: 0.079874
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 2.304214, Test acc: 0.076322
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: base, Optimizer: adam, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 2.042372, train acc: 0.506284, valid loss: 1.564615, valid acc: 0.708259
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 0.244690, train acc: 0.931046, valid loss: 0.320426, valid acc: 0.907552
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 0.214992, train acc: 0.940557, valid loss: 0.308222, valid acc: 0.911719
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 0.288471, Test acc: 0.915865
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: mnist, Model: base, Optimizer: adam, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.306259, train acc: 0.130265, valid loss: 2.306209, valid acc: 0.128664
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.303257, train acc: 0.136889, valid loss: 2.303405, valid acc: 0.135677
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.302710, train acc: 0.138587, valid loss: 2.302664, valid acc: 0.137612
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.302710, Test acc: 0.138021
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: mnist, Model: base, Optimizer: adam, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.297611, train acc: 0.104789, valid loss: 2.297625, valid acc: 0.104483
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.285464, train acc: 0.103261, valid loss: 2.286030, valid acc: 0.104613
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.281743, train acc: 0.104620, valid loss: 2.282836, valid acc: 0.104929
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 2.281517, Test acc: 0.103265
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: base, Optimizer: rmsprop, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 1.236588, train acc: 0.625340, valid loss: 0.695586, valid acc: 0.799200
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 0.209884, train acc: 0.943274, valid loss: 0.298579, valid acc: 0.914900
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 0.180347, train acc: 0.951087, valid loss: 0.285544, valid acc: 0.918527
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 0.264794, Test acc: 0.924379
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: mnist, Model: base, Optimizer: rmsprop, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.302171, train acc: 0.116168, valid loss: 2.301758, valid acc: 0.113839
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.298770, train acc: 0.120414, valid loss: 2.298958, valid acc: 0.116239
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.298389, train acc: 0.119565, valid loss: 2.298442, valid acc: 0.116481
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.298774, Test acc: 0.115485
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: mnist, Model: base, Optimizer: rmsprop, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.302205, train acc: 0.104450, valid loss: 2.300348, valid acc: 0.106064
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.284500, train acc: 0.123981, valid loss: 2.285077, valid acc: 0.122228
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.281368, train acc: 0.130095, valid loss: 2.282012, valid acc: 0.128032
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 2.280307, Test acc: 0.130409
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: first, Optimizer: sgd, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 2.302332, train acc: 0.108356, valid loss: 2.303765, valid acc: 0.087109
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 2.299380, train acc: 0.109715, valid loss: 2.299187, valid acc: 0.097210
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 2.297612, train acc: 0.108865, valid loss: 2.298084, valid acc: 0.099628
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 2.296839, Test acc: 0.095753
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: mnist, Model: first, Optimizer: sgd, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.311230, train acc: 0.083390, valid loss: 2.310173, valid acc: 0.085138
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.311788, train acc: 0.081182, valid loss: 2.310183, valid acc: 0.085156
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.313166, train acc: 0.085598, valid loss: 2.310148, valid acc: 0.085156
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.310661, Test acc: 0.081130
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: mnist, Model: first, Optimizer: sgd, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.305373, train acc: 0.097486, valid loss: 2.304152, valid acc: 0.094959
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.305390, train acc: 0.092731, valid loss: 2.304131, valid acc: 0.094885
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.304550, train acc: 0.094939, valid loss: 2.304136, valid acc: 0.094940
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 2.304490, Test acc: 0.093550
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: first, Optimizer: adam, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 1.864410, train acc: 0.441916, valid loss: 1.060997, valid acc: 0.755487
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 0.300161, train acc: 0.915761, valid loss: 0.274760, valid acc: 0.919978
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 0.239532, train acc: 0.929688, valid loss: 0.248421, valid acc: 0.927158
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 0.230799, Test acc: 0.928986
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: mnist, Model: first, Optimizer: adam, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.305046, train acc: 0.112092, valid loss: 2.301588, valid acc: 0.104483
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.300841, train acc: 0.112432, valid loss: 2.297994, valid acc: 0.104297
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.300595, train acc: 0.114810, valid loss: 2.297045, valid acc: 0.104576
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.297417, Test acc: 0.102764
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: mnist, Model: first, Optimizer: adam, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.302675, train acc: 0.103770, valid loss: 2.301797, valid acc: 0.087723
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.287075, train acc: 0.142493, valid loss: 2.283457, valid acc: 0.189974
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.281359, train acc: 0.165251, valid loss: 2.278595, valid acc: 0.231510
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 2.276759, Test acc: 0.240284
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: first, Optimizer: rmsprop, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 1.205791, train acc: 0.601562, valid loss: 0.494463, valid acc: 0.866462
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 0.222697, train acc: 0.933933, valid loss: 0.223763, valid acc: 0.932813
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 0.175803, train acc: 0.952276, valid loss: 0.212564, valid acc: 0.937054
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 0.196338, Test acc: 0.940204
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: mnist, Model: first, Optimizer: rmsprop, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.303427, train acc: 0.109545, valid loss: 2.300250, valid acc: 0.133073
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.296685, train acc: 0.125170, valid loss: 2.295294, valid acc: 0.144624
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.296718, train acc: 0.125510, valid loss: 2.294381, valid acc: 0.146633
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.293618, Test acc: 0.152444
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: mnist, Model: first, Optimizer: rmsprop, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.301405, train acc: 0.096637, valid loss: 2.296022, valid acc: 0.123865
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.274464, train acc: 0.170856, valid loss: 2.272902, valid acc: 0.277139
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.269834, train acc: 0.189878, valid loss: 2.267886, valid acc: 0.307217
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 2.265989, Test acc: 0.322817
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: second, Optimizer: sgd, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 2.353436, train acc: 0.111073, valid loss: 2.285188, valid acc: 0.119364
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 1.636941, train acc: 0.653533, valid loss: 1.644286, valid acc: 0.642578
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 1.530652, train acc: 0.705842, valid loss: 1.546231, valid acc: 0.690923
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 1.503562, Test acc: 0.714042
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: mnist, Model: second, Optimizer: sgd, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.365533, train acc: 0.109885, valid loss: 2.322876, valid acc: 0.114323
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.364332, train acc: 0.110904, valid loss: 2.361091, valid acc: 0.114156
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.362197, train acc: 0.113791, valid loss: 2.360575, valid acc: 0.113504
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.365102, Test acc: 0.110276
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: mnist, Model: second, Optimizer: sgd, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.395057, train acc: 0.101902, valid loss: 2.317970, valid acc: 0.098456
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.389218, train acc: 0.103091, valid loss: 2.389349, valid acc: 0.100818
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.388330, train acc: 0.100713, valid loss: 2.387742, valid acc: 0.101674
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:86: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ===== Test Start =====
# Test loss: 2.388103, Test acc: 0.103265
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: second, Optimizer: adam, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 0.946438, train acc: 0.798404, valid loss: 0.911027, valid acc: 0.889007
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 0.018411, train acc: 1.000000, valid loss: 0.161634, valid acc: 0.951507
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 0.009776, train acc: 1.000000, valid loss: 0.158629, valid acc: 0.951637
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 0.139257, Test acc: 0.958433
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: mnist, Model: second, Optimizer: adam, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.342263, train acc: 0.109715, valid loss: 2.306307, valid acc: 0.113672
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.258336, train acc: 0.168139, valid loss: 2.264866, valid acc: 0.161179
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.238209, train acc: 0.181895, valid loss: 2.245800, valid acc: 0.175428
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.241261, Test acc: 0.181090
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: mnist, Model: second, Optimizer: adam, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.344636, train acc: 0.104620, valid loss: 2.288761, valid acc: 0.147656
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 1.960940, train acc: 0.421365, valid loss: 1.959860, valid acc: 0.431603
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 1.879574, train acc: 0.485734, valid loss: 1.884749, valid acc: 0.491983
# ...
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.410482, train acc: 0.115999, valid loss: 2.295454, valid acc: 0.111607
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.402434, train acc: 0.115999, valid loss: 2.296986, valid acc: 0.144215
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.402414, train acc: 0.117357, valid loss: 2.298220, valid acc: 0.142299
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.299390, Test acc: 0.140525
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: fmnist, Model: third, Optimizer: sgd, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.418377, train acc: 0.112432, valid loss: 2.304891, valid acc: 0.117653
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.410536, train acc: 0.113621, valid loss: 2.290513, valid acc: 0.144048
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.395650, train acc: 0.117357, valid loss: 2.290438, valid acc: 0.143806
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 2.287716, Test acc: 0.144932
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: fmnist, Model: third, Optimizer: adam, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 1.376282, train acc: 0.584749, valid loss: 1.041817, valid acc: 0.725856
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 0.417356, train acc: 0.855299, valid loss: 0.416772, valid acc: 0.852641
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 0.337290, train acc: 0.884171, valid loss: 0.396350, valid acc: 0.859189
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 0.430492, Test acc: 0.850461
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: fmnist, Model: third, Optimizer: adam, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.493330, train acc: 0.086957, valid loss: 2.321182, valid acc: 0.100651
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.408111, train acc: 0.117527, valid loss: 2.284676, valid acc: 0.147005
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.386239, train acc: 0.116508, valid loss: 2.266927, valid acc: 0.160938
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.263793, Test acc: 0.162059
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: fmnist, Model: third, Optimizer: adam, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.430860, train acc: 0.098505, valid loss: 2.288570, valid acc: 0.100112
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 2.124191, train acc: 0.225374, valid loss: 1.989619, valid acc: 0.437630
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 2.063697, train acc: 0.253397, valid loss: 1.930810, valid acc: 0.495647
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 1.918940, Test acc: 0.504207
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: fmnist, Model: third, Optimizer: rmsprop, lr: 0.001, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 1.017216, train acc: 0.660326, valid loss: 0.690491, valid acc: 0.778646
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 0.368935, train acc: 0.868886, valid loss: 0.401684, valid acc: 0.855990
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 0.319053, train acc: 0.888417, valid loss: 0.387924, valid acc: 0.861403
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# ===== Test Start =====
# Test loss: 0.420659, Test acc: 0.851963
# Adjusting learning rate of group 0 to 1.0000e-06.
# ===== Data: fmnist, Model: third, Optimizer: rmsprop, lr: 1e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-06.
# Epoch: 0, train loss: 2.494663, train acc: 0.102242, valid loss: 2.313020, valid acc: 0.107775
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 1.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 5.0000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Epoch: 10, train loss: 2.378033, train acc: 0.146909, valid loss: 2.243998, valid acc: 0.217801
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 2.5000e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 1.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Epoch: 20, train loss: 2.367018, train acc: 0.142663, valid loss: 2.224357, valid acc: 0.232068
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 6.2500e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 3.1250e-08.
# Adjusting learning rate of group 0 to 1.5625e-08.
# ===== Test Start =====
# Test loss: 2.224216, Test acc: 0.231270
# Adjusting learning rate of group 0 to 5.0000e-06.
# ===== Data: fmnist, Model: third, Optimizer: rmsprop, lr: 5e-06, max_epochs: 30 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 5.0000e-06.
# Epoch: 0, train loss: 2.337855, train acc: 0.139436, valid loss: 2.240114, valid acc: 0.224572
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 5.0000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 2.5000e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Epoch: 10, train loss: 1.951937, train acc: 0.336787, valid loss: 1.825221, valid acc: 0.600112
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 1.2500e-06.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 6.2500e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Epoch: 20, train loss: 1.886136, train acc: 0.386039, valid loss: 1.773592, valid acc: 0.613783
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 3.1250e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 1.5625e-07.
# Adjusting learning rate of group 0 to 7.8125e-08.
# ===== Test Start =====
# Test loss: 1.767212, Test acc: 0.613181

# %%
# MNIST dataset에 대해 여러분이 찾은 최적의 조건으로 학습을 한 번 더 진행해 주세요.
d = "mnist"
m = "third"
opt = "rmsprop"
lr = 0.001
max_epochs = 500

model = get_model(model_name = m)
trainer = Trainer(model=model, opt=opt, lr=lr, has_scheduler=True)
print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
trainer.test(test_loader=datas[d][2])
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.
# ===== Data: mnist, Model: third, Optimizer: rmsprop, lr: 0.001, max_epochs: 500 =====
# ===== Train Start =====
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch: 0, train loss: 0.825274, train acc: 0.777174, valid loss: 0.450094, valid acc: 0.901711
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 1.0000e-03.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 5.0000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Epoch: 10, train loss: 0.153460, train acc: 0.955163, valid loss: 0.191157, valid acc: 0.941332
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 2.5000e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 1.2500e-04.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Epoch: 20, train loss: 0.107631, train acc: 0.972656, valid loss: 0.183832, valid acc: 0.943601
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 6.2500e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 3.1250e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# Epoch: 30, train loss: 0.112741, train acc: 0.967561, valid loss: 0.182397, valid acc: 0.944141
# Adjusting learning rate of group 0 to 1.5625e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# Adjusting learning rate of group 0 to 1.5625e-05.
# Adjusting learning rate of group 0 to 7.8125e-06.
# Adjusting learning rate of group 0 to 7.8125e-06.
# Adjusting learning rate of group 0 to 7.8125e-06.
# Adjusting learning rate of group 0 to 7.8125e-06.
# Adjusting learning rate of group 0 to 7.8125e-06.
# Adjusting learning rate of group 0 to 3.9063e-06.
# Adjusting learning rate of group 0 to 3.9063e-06.
# Epoch: 40, train loss: 0.095858, train acc: 0.975204, valid loss: 0.182437, valid acc: 0.943955
# Adjusting learning rate of group 0 to 3.9063e-06.
# Adjusting learning rate of group 0 to 3.9063e-06.
# Adjusting learning rate of group 0 to 3.9063e-06.
# Adjusting learning rate of group 0 to 1.9531e-06.
# Adjusting learning rate of group 0 to 1.9531e-06.
# Adjusting learning rate of group 0 to 1.9531e-06.
# Adjusting learning rate of group 0 to 1.9531e-06.
# Adjusting learning rate of group 0 to 1.9531e-06.
# Adjusting learning rate of group 0 to 9.7656e-07.
# Adjusting learning rate of group 0 to 9.7656e-07.
# Epoch: 50, train loss: 0.105307, train acc: 0.970618, valid loss: 0.182674, valid acc: 0.943992
# Adjusting learning rate of group 0 to 9.7656e-07.
# Adjusting learning rate of group 0 to 9.7656e-07.
# Adjusting learning rate of group 0 to 9.7656e-07.
# Adjusting learning rate of group 0 to 4.8828e-07.
# Adjusting learning rate of group 0 to 4.8828e-07.
# Adjusting learning rate of group 0 to 4.8828e-07.
# Adjusting learning rate of group 0 to 4.8828e-07.
# Adjusting learning rate of group 0 to 4.8828e-07.
# Adjusting learning rate of group 0 to 2.4414e-07.
# Adjusting learning rate of group 0 to 2.4414e-07.
# Epoch: 60, train loss: 0.111705, train acc: 0.969260, valid loss: 0.181744, valid acc: 0.944159
# Adjusting learning rate of group 0 to 2.4414e-07.
# Adjusting learning rate of group 0 to 2.4414e-07.
# Adjusting learning rate of group 0 to 2.4414e-07.
# Adjusting learning rate of group 0 to 1.2207e-07.
# Adjusting learning rate of group 0 to 1.2207e-07.
# Adjusting learning rate of group 0 to 1.2207e-07.
# Adjusting learning rate of group 0 to 1.2207e-07.
# Adjusting learning rate of group 0 to 1.2207e-07.
# Adjusting learning rate of group 0 to 6.1035e-08.
# Adjusting learning rate of group 0 to 6.1035e-08.
# Epoch: 70, train loss: 0.102929, train acc: 0.972656, valid loss: 0.182206, valid acc: 0.943936
# Adjusting learning rate of group 0 to 6.1035e-08.
# Adjusting learning rate of group 0 to 6.1035e-08.
# Adjusting learning rate of group 0 to 6.1035e-08.
# Adjusting learning rate of group 0 to 3.0518e-08.

# %%
# FashionMNIST dataset에 대해 여러분이 찾은 최적의 조건으로 학습을 한 번 더 진행해 주세요.
d = "fmnist"
m = "second"
opt = "rmsprop"
lr = 0.001
max_epochs = 500

model = get_model(model_name = m)
trainer = Trainer(model=model, opt=opt, lr=lr, has_scheduler=True)
print(f"===== Data: {d}, Model: {m}, Optimizer: {opt}, lr: {lr}, max_epochs: {max_epochs} =====")
trainer.train(data_name=d, train_loader=datas[d][0], valid_loader=datas[d][1], max_epochs=max_epochs)
trainer.test(test_loader=datas[d][2])
# Out:
# ===== Data: fmnist, Model: base, Optimizer: sgd, lr: 0.0, max_epochs: 10 =====
# ===== Train Start =====
# Epoch: 0, train loss: 2.299460, train acc: 0.096856, valid loss: 2.300806, valid acc: 0.096807
# ===== Test Start =====
# Test loss: 2.299201, Test acc: 0.097656
